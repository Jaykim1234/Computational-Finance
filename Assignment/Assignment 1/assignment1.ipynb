# %% [markdown]
# # Assignment 1

# %% [markdown]
# **Deadline**:  Sunday 21 November, 23.59.
#
# Your notebook should not give errors when executed with `Run All`. Please submit your answers via [Canvas](https://canvas.uva.nl/courses/25150/assignments/248822).
#
# | |Name |Student number|Email|
# |:-|:----|:-------------|:----|
# |1.|  |        |     |
# |2.|  |        |     |
#
# ****Hand in the following****:
# * Your notebook. N.B. **click on `Kernel`, then `Restart & Run All`** before submitting, see notes.
# * A (printed) pdf version of your notebook.
#
# ****NOTES****:
# * The assignment is a partial stand-in for a final examination, so the usual rules regarding plagiarism and fraud apply, with all attendant consequences. Code found on the internet or elsewhere is not acceptable as a solution.
# * Before submitting your work, **click on `Kernel`, then `Restart & Run All`** and verify that your notebook produces the desired results and does not error.
# * Make sure that any function you write has a docstring, and comments where appropriate.
# * Some questions require you to write code to obtain a numerical result (e.g., an option price). In that case, don't just give the function, but also the result of calling it with the given parameter values (i.e., the numerial value that it returns). If your function uses random numbers, then set the seed to 0 before calling it. This makes it much easier to grade the assignments (at least as long as the answer is correct).
# * How to convert your notebook to pdf: The easiest way is probably to use your browser's print functionality: e.g. in Chrome, press the three dots to go to Options, select 'Print...', and then select 'save as pdf' as Destination. I usually set it to 70% zoom such that the output fits the printed pdf pages.
#
# **Declaration of Originality**:
#
# We whose names are given under 1. and 2. above declare that
# 1. These solutions are solely our own work.
# 2. We have not made these solutions available to any other student.

# %% [markdown]
# ## Question 1: Testing the CAPM
# The CAPM implies that
# \begin{equation*}
# E(R_{i}-R_{f})=\beta _{i}E(R_{m}-R_{f}),\qquad \beta _{i}=\frac{\mathrm{cov}%
# (R_{i},R_{m})}{\mathrm{var}(R_{m})},
# \end{equation*}
#
# where $R_i$ is the return on a stock, and $R_m$ is the market return. Suppose we have time series on $n$ different stock or portfolio returns $\{R_{it},i=1,\ldots ,n\}_{t=1}^{T}$ and on a "market return" (value weighted index) $\{R_{mt}\}_{t=1}^{T}$.  We also have observations on a risk-free interest rate $\{R_{ft}\}_{t=1}^{T}$ and construct with these the excess returns $r_{it}=R_{it}-R_{ft}$ and $r_{mt}=R_{mt}-R_{ft}$. Now $\beta_i$ can be estimated from the time-series regression \begin{equation*}
# r_{it}=\alpha _{i}+\beta _{i}r_{mt}+\varepsilon _{it},\qquad t=1,\ldots ,T.
# \end{equation*}
#
# One way to test the CAPM is as follows: denote by $\bar{r}_{i}$
# and $\hat{\beta}_{i}$ the average excess return and estimated $\beta$ of stock $i$. If the model $E(r_{i})=\beta_{i}E(r_{m})$ is valid, then $(\hat{\beta}_{i},\bar{r}_{i})$ should lie on a line with zero intercept and slope $\lambda =E(r_{mt})$. This line is called the *security market line*, and $\lambda$ is known as the *market risk premium*.
#
# We can estimate $\lambda $ by OLS in the cross-section regression
# \begin{equation*}
# \bar{r}_{i}=\lambda \hat{\beta}_{i}+\alpha _{i},\qquad i=1,\ldots ,n.
# \end{equation*}
# Note that $\hat{\beta_i}$ is the regressor, $\lambda$ the coefficient, and $\alpha_i$ the error term.
#
# The assignment is to estimate the CAPM betas of the 30 constituent stocks of the Dow (using the return on the Dow as the market return, and the 3 month T-bill rate as the risk-free rate), then estimate the above cross-section regression, and finally make a plot of the security market line superimposed on a scatter plot of $(\hat{\beta}_{i},\bar{r}_{i})$.

# %% [markdown]
# **1.1** Import the relevant libraries:

# %%
import pandas as pd
import numpy as np
import pandas_datareader.data as web
import datetime
import matplotlib
from   matplotlib.pyplot import figure
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import statsmodels.api as sm
import scipy.stats as stats 
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %% [markdown]
# **1.2** Obtain, from the FRED database, the daily adjusted closing prices of the Dow Jones Industrial Average (DJIA) from 31/12/2011 to 30/09/2021. Convert them into percentage log returns $r_t=100 \times \log(P_t/P_{t-1})$ and store them in a DataFrame `df_1`, which has the date as index and 'DJIA' as column name:

# %%
start = datetime.datetime(2011,12,31)
end = datetime.datetime(2021,9,30)

# The initial index was DJIA. So we have resetted the index to set 'Date' as an index.
df_1 = web.DataReader('DJIA','fred',start,end).reset_index()

# Change columns of 'DATE' into Datetime data
df_1['DATE'] = pd.to_datetime(df_1['DATE'])

# Set 'Date' as index
df_1.set_index('DATE', inplace = True)
df_1
# Out:
#                 DJIA
# DATE
# 2012-01-02       NaN
# 2012-01-03  12397.38
# 2012-01-04  12418.42
# 2012-01-05  12415.70
# 2012-01-06  12359.92
# ...              ...
# 2021-09-24  34798.00
# 2021-09-27  34869.37
# 2021-09-28  34299.99
# 2021-09-29  34390.72
# 2021-09-30  33843.92
#
# [2544 rows x 1 columns]

# %%
df_1 = 100*(np.log(df_1) - np.log(df_1).shift(1));df_1
# Out:
#                 DJIA
# DATE
# 2012-01-02       NaN
# 2012-01-03       NaN
# 2012-01-04  0.169569
# 2012-01-05 -0.021905
# 2012-01-06 -0.450282
# ...              ...
# 2021-09-24  0.095396
# 2021-09-27  0.204888
# 2021-09-28 -1.646373
# 2021-09-29  0.264170
# 2021-09-30 -1.602739
#
# [2544 rows x 1 columns]

# %% [markdown]
# **1.3** Obtain, also from the FRED database, daily data on the 3-month T-bill rate (DTB3) for the same period and divide them by 365:

# %%
start = datetime.datetime(2011,12,31)
end   = datetime.datetime(2021,9,30)

rf    = web.DataReader('DTB3','fred',start,end).reset_index()

# Change columns of 'DATE' into Datetime data
rf['DATE'] = pd.to_datetime(rf['DATE'])

# Set 'DATE' as index
rf.set_index('DATE', inplace = True)

# Divide T-bill rate by 365
rf = rf/365; rf
# Out:
#                 DTB3
# DATE
# 2012-01-02       NaN
# 2012-01-03  0.000055
# 2012-01-04  0.000055
# 2012-01-05  0.000055
# 2012-01-06  0.000055
# ...              ...
# 2021-09-24  0.000082
# 2021-09-27  0.000110
# 2021-09-28  0.000110
# 2021-09-29  0.000110
# 2021-09-30  0.000110
#
# [2544 rows x 1 columns]

# %% [markdown]
# **1.4** The csv file `tickerdata.csv` which has been provided with this assignment contains the adjusted closing prices for the 30 constituent stocks of the Dow Jones.
#
# Import the dataset into a second DataFrame `df_2`, convert the `Date`-column to datetime, and make the `Date`-column the new index:

# %%
df_2 = pd.read_csv(r'.\tickerdata.csv', index_col=0).reset_index()

# Change columns of 'DATE' into Datetime data
df_2['Date'] = pd.to_datetime(df_2['Date'])

# Set 'DATE' as index
df_2.set_index('Date', inplace = True)

df_2.head(100)
# Out:
#                  AAPL       AMGN        AXP         BA        CAT        CRM  \
# 2012-05-24 -0.095920  0.755888
#
# [100 rows x 30 columns]

# %% [markdown]
# **1.6** Concatenate DataFrames `df_1` and `df_2` along the common axis to a final DataFrame `df`:
#
#
# Notes (also hold for next question):
# * Need to specify the axis
# * `dtype` of the indices should be the same

# %%
# Check whether dtype of the indices are the same
print(df_1.index.dtype, df_2.index.dtype, rf.index.dtype)
# Out:
# datetime64[ns] datetime64[ns] datetime64[ns]

# %%
# Concatenate two dataframes.
df = pd.concat([df_1,df_2], axis =1); df
# Out:
#                 DJIA      AAPL      AMGN       AXP        BA       CAT  \
# 2012-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2012-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2012-01-04  0.169569  0.535956 -0.547425  0.062226  0.148085  0.921486
# 2012-01-05 -0.021905  1.104125  1.014286  1.154191 -1.082108  0.703906
# 2012-01-06 -0.450282  1.039931  0.541931 -1.092031  0.610145  0.250963
# ...              ...       ...       ...       ...       ...       ...
# 2021-09-24  0.095396  0.061274 -0.671865  1.352151  0.131073  0.101674
# 2021-09-27  0.204888 -1.060603 -0.234346  0.595762  1.243425  1.602772
# 2021-09-28 -1.646373 -2.408910 -0.394940 -2.074896 -2.598605  0.274624
# 2021-09-29  0.264170  0.646205  1.231371 -0.928408  3.132508 -1.345338
# 2021-09-30 -1.602739 -0.935541 -1.052518 -2.365398 -2.434433 -3.027111
#
#                  CRM      CSCO       CVX       DIS  ...       MRK      MSFT  \
# 2012-01-02       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2012-01-03       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2012-01-04 -3.745146  1.913936 -0.172336  1.399691  ...  0.104367  2.326118
# 2012-01-05  1.314662 -0.369298 -0.985045  1.659240  ...  1.037890  1.016695
# 2012-01-06  2.292049 -0.370666 -0.726731  1.032639  ... -0.699402  1.541527
# ...              ...       ...       ...       ...  ...       ...       ...
# 2021-09-24  2.757995  0.070532  0.538226 -0.141945  ...  0.763671 -0.070125
# 2021-09-27 -2.105122 -0.903058  2.328545  1.275913  ... -0.340206 -1.745560
# 2021-09-28 -2.681512 -1.252922  0.378035 -2.120376  ... -0.054542 -3.687525
# 2021-09-29 -0.655885 -0.072076 -0.029028 -1.059924  ...  2.385393  0.169161
# 2021-09-30  0.265821 -1.910711 -1.836173 -2.053601  ...  0.026637 -0.735085
#
#                  NKE        PG       TRV       UNH         V        VZ  \
# 2012-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2012-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2012-01-04  1.445960 -0.044876 -0.407684  1.446047 -1.802742 -1.317454
# 2012-01-05 -0.061117 -0.420049  0.982379  0.667762  0.748555 -0.690995
# 2012-01-06 -0.173342 -0.240820  0.033735  0.360654 -1.184507 -0.286570
# ...              ...       ...       ...       ...       ...       ...
# 2021-09-24 -6.464718 -0.444840  0.281620 -0.233100  1.426421 -0.091918
# 2021-09-27 -1.041573 -1.325359 -0.108722 -0.445621 -0.862986  0.183758
# 2021-09-28 -1.868187 -0.758202 -1.807776 -1.654491 -1.775250 -0.570747
# 2021-09-29  0.494304  1.012014  0.901520  0.448046  0.495311  0.405382
# 2021-09-30 -0.542496 -1.575511 -1.870438 -2.444668 -1.748923 -0.682730
#
#                  WBA       WMT
# 2012-01-02       NaN       NaN
# 2012-01-03       NaN       NaN
# 2012-01-04 -0.698128 -1.032997
# 2012-01-05 -0.335604 -0.486852
# 2012-01-06  1.094206 -0.709360
# ...              ...       ...
# 2021-09-24 -0.310009  0.279775
# 2021-09-27  1.009169 -0.644665
# 2021-09-28 -1.646483 -2.409020 -0.395049 -2.075005 -2.598715  0.274514
# 2021-09-29  0.264060  0.646095  1.231261 -0.928517  3.132398 -1.345448
# 2021-09-30 -1.602849 -0.935650 -1.052628 -2.365507 -2.434543 -3.027220
#
#                  CRM      CSCO       CVX       DIS  ...       MRK      MSFT  \
# 2012-01-04 -3.745201  1.913882 -0.172391  1.399636  ...  0.104312  2.326064
# 2012-01-05  1.314607 -0.369352 -0.985099  1.659185  ...  1.037835  1.016640
# 2012-01-06  2.291995 -0.370721 -0.726786  1.032584  ... -0.699457  1.541472
# 2012-01-09 -0.307245  0.634572  1.083546 -0.401709  ... -0.208185 -1.325012
# 2012-01-10  3.931561 -0.740808 -0.393557 -0.302430  ...  0.337979  0.359771
# ...              ...       ...       ...       ...  ...       ...       ...
# 2021-09-24  2.757913  0.070449  0.538144 -0.142027  ...  0.763589 -0.070207
# 2021-09-27 -2.105231 -0.903168  2.328436  1.275804  ... -0.340315 -1.745670
# 2021-09-28 -2.681622 -1.253031  0.377925 -2.120485  ... -0.054651 -3.687634
# 2021-09-29 -0.655994 -0.072186 -0.029137 -1.060034  ...  2.385283  0.169051
# 2021-09-30  0.265711 -1.910820 -1.836283 -2.053711  ...  0.026527 -0.735194
#
#                  NKE        PG       TRV       UNH         V        VZ  \
# 2012-01-04  1.445906 -0.044931 -0.407739  1.445992 -1.802797 -1.317509
# 2012-01-05 -0.061172 -0.420104  0.982324  0.667707  0.748501 -0.691050
# 2012-01-06 -0.173396 -0.240875  0.033680  0.360599 -1.184562 -0.286625
# 2012-01-09  0.366692  0.421009  0.571168 -0.113769 -0.807558  0.104271
# 2012-01-10  0.121881 -0.466301  0.684499 -0.189927 -0.100214  0.519852
# ...              ...       ...       ...       ...       ...       ...
# 2021-09-24 -6.464800 -0.444922  0.281538 -0.233183  1.426339 -0.092000
# 2021-09-27 -1.041683 -1.325469 -0.108831 -0.445730 -0.863096  0.183648
# 2021-09-28 -1.868297 -0.758312 -1.807885 -1.654601 -1.775360 -0.570857
# 2021-09-29  0.494194  1.011904  0.901411  0.447937  0.495201  0.405273
# 2021-09-30 -0.542606 -1.575621 -1.870548 -2.444778 -1.749033 -0.682840
#
#                  WBA       WMT
# 2012-01-04 -0.698183 -1.033052
# 2012-01-05 -0.335658 -0.486907
# 2012-01-06  1.094151 -0.709415
# 2012-01-09  1.261627  0.304599
# 2012-01-10  2.651065 -0.236870
# ...              ...       ...
# 2021-09-24 -0.310091  0.279693
# 2021-09-27  1.009059 -0.644775
# 2021-09-28 -1.465713 -1.237968
# 2021-09-29  1.280897 -0.042822
# 2021-09-30 -3.467458 -0.757741
#
# [2346 rows x 31 columns]

# %% [markdown]
# **1.9** Use a `for` loop to estimate a CAPM time series regression for each stock, and store the estimated slope coefficient in a list.
#
# *Hint*: use string interpolation to construct the regression equation and use the list `tickers` below, containing the ticker symbols of all 30 constituent stocks of the DJIA.

# %%
tickers = ["AAPL", "AMGN", "AXP", "BA", "CAT", "CRM", "CSCO", "CVX", "DIS", "DD",
            "GS", "HD", "HON", "IBM", "INTC", "JNJ", "JPM", "KO", "MCD", "MMM", 
            "MRK", "MSFT", "NKE", "PG", "TRV", "UNH", "V", "VZ", "WBA","WMT"]

# %%
# Make an empty list to store beta coefficients.
coefficients = []

for company in tickers:
    # Calculate the beta coefficient [Y: each companies' excess return , X: market excess return(DJIA)]
    results = smf.ols(f'{company} ~ + DJIA', data = df ).fit(cov_type ='HAC', cov_kwds = {'maxlags':5})
    
    # Append coefficients value to the list
    coefficients.append(list(results.params)[1]) 
    
print(coefficients)
# Out:
# [1.0123805371791255, 0.843988927715863, 1.2671965532092107, 1.546305665399263, 1.1613003720474417, 1.058424903768695, 0.9946973373365443, 1.2105287443091646, 0.9877328533294722, 1.1823931518044408, 1.2938977147341713, 0.9904804122066533, 1.068795699806526, 0.9701575607860277, 1.1111529041488155, 0.6658307234508308, 1.2496648246365416, 0.6751687869344227, 0.7802988996874127, 0.9078587551384667, 0.6844055685129881, 1.0580233898967404, 0.9307321413785774, 0.6098461363854872, 0.9614686396139731, 1.0044320758791154, 1.0803973954604005, 0.5364298211547747, 0.840926007747768, 0.5286295956180211]

# %% [markdown]
# **1.10** Create a new dataframe that has `tickers` as index, and two columns: `beta`, containing the 30 estimated betas, and `meanret`, containing the mean excess returns of the 30 stocks:

# %%
# Make a beta dataframe that contains the coefficient value of companies
beta = pd.DataFrame(coefficients, index=tickers, columns=['beta']); beta

# Make a dataframe that has the mean excess return of each companies during the whole period
meanret = pd.DataFrame(np.mean(df[tickers], axis = 0), index= tickers, columns=['meanret']); meanret

# Concatenate beta and meanret dataframes 
new_df = pd.concat([beta, meanret], axis =1); new_df
# Out:
#           beta   meanret
# AAPL  1.012381  0.089613
# AMGN  0.843989  0.061284
# AXP   1.267197  0.055363
# BA    1.546306  0.051763
# CAT   1.161300  0.047535
# CRM   1.058425  0.092926
# CSCO  0.994697  0.052445
# CVX   1.210529  0.015262
# DIS   0.987733  0.062255
# DD    1.182393  0.045482
# GS    1.293898  0.062216
# HD    0.990480  0.092967
# HON   1.068796  0.067847
# IBM   0.970158 -0.002944
# INTC  1.111153  0.039253
# JNJ   0.665831  0.050801
# JPM   1.249665  0.079601
# KO    0.675169  0.029456
# MCD   0.780299  0.043457
# MMM   0.907859  0.043073
# MRK   0.684406  0.043942
# MSFT  1.058023  0.100872
# NKE   0.930732  0.079308
# PG    0.609846  0.041516
# TRV   0.961469  0.056805
# UNH   1.004432  0.079092
# V     1.080397  0.083598
# VZ    0.536430  0.028009
# WBA   0.840926  0.018677
# WMT   0.528630  0.036966

# %% [markdown]
# **1.11** Estimate the security market line by a cross-sectional regression (without intercept), and print a summary of the result:

# %%
coefficients_c_s = []
for company in tickers:
    results = smf.ols(f'{company} ~ -1 + DJIA', data = df ).fit(cov_type ='HAC', cov_kwds = {'maxlags':5})
    print(results.summary2())
# Out:
#                         Results: Ordinary least squares
# ===============================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.362
# Dependent Variable:     AAPL             AIC:                         8346.2905
# Date:                   2021-11-17 15:51 BIC:                         8352.0510
# No. Observations:       2346             Log-Likelihood:              -4172.1
# Df Model:               1                F-statistic:                 938.0
# Df Residuals:           2345             Prob (F-statistic):          1.42e-173
# R-squared (uncentered): 0.363            Scale:                       2.0531
# -------------------------------------------------------------------------------------
#            Coef.        Std.Err.          z          P>|z|        [0.025       0.975]
# -------------------------------------------------------------------------------------
# DJIA       1.0141         0.0331       30.6270       0.0000       0.9492       1.0790
# -------------------------------------------------------------------------------
# Omnibus:                 402.667           Durbin-Watson:              1.913
# Prob(Omnibus):           0.000             Jarque-Bera (JB):           6109.564
# Skew:                    -0.321            Prob(JB):                   0.000
# Kurtosis:                10.880            Condition No.:              1
# ===============================================================================
#
#                         Results: Ordinary least squares
# ===============================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.322
# Dependent Variable:     AMGN             AIC:                         7910.2937
# Date:                   2021-11-17 15:51 BIC:                         7916.0542
# No. Observations:       2346             Log-Likelihood:              -3954.1
# Df Model:               1                F-statistic:                 503.5
# Df Residuals:           2345             Prob (F-statistic):          3.54e-101
# R-squared (uncentered): 0.322            Scale:                       1.7049
# -------------------------------------------------------------------------------------
#            Coef.        Std.Err.          z          P>|z|        [0.025       0.975]
# -------------------------------------------------------------------------------------
# DJIA       0.8450         0.0377       22.4386       0.0000       0.7712       0.9188
# -------------------------------------------------------------------------------
# Omnibus:                 314.304           Durbin-Watson:              1.968
# Prob(Omnibus):           0.000             Jarque-Bera (JB):           3857.383
# Skew:                    -0.056            Prob(JB):                   0.000
# Kurtosis:                9.281             Condition No.:              1
# ===============================================================================
#
#                         Results: Ordinary least squares
# ===============================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.578
# Dependent Variable:     AXP              AIC:                         7332.3606
# Date:                   2021-11-17 15:51 BIC:                         7338.1211
# No. Observations:       2346             Log-Likelihood:              -3665.2
# Df Model:               1                F-statistic:                 754.9
# Df Residuals:           2345             Prob (F-statistic):          2.55e-144
# R-squared (uncentered): 0.578            Scale:                       1.3327
# -------------------------------------------------------------------------------------
#            Coef.        Std.Err.          z          P>|z|        [0.025       0.975]
# -------------------------------------------------------------------------------------
# DJIA       1.2674         0.0461       27.4758       0.0000       1.1770       1.3578
# -------------------------------------------------------------------------------
# Omnibus:                 736.231          Durbin-Watson:             2.009
# Prob(Omnibus):           0.000            Jarque-Bera (JB):          103285.585
# Skew:                    0.298            Prob(JB):                  0.000
# Kurtosis:                35.500           Condition No.:             1
# ===============================================================================
#
#                         Results: Ordinary least squares
# ===============================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.505
# Dependent Variable:     BA               AIC:                         8953.7619
# Date:                   2021-11-17 15:51 BIC:                         8959.5224
# No. Observations:       2346             Log-Likelihood:              -4475.9
# Df Model:               1                F-statistic:                 535.9
# Df Residuals:           2345             Prob (F-statistic):          6.09e-107
# R-squared (uncentered): 0.505            Scale:                       2.6599
# -------------------------------------------------------------------------------------
#            Coef.        Std.Err.          z          P>|z|        [0.025       0.975]
# -------------------------------------------------------------------------------------
# DJIA       1.5460         0.0668       23.1486       0.0000       1.4151       1.6768
# -------------------------------------------------------------------------------
# Omnibus:                  694.604          Durbin-Watson:             1.846
# Prob(Omnibus):            0.000            Jarque-Bera (JB):          31878.323
# Skew:                     0.630            Prob(JB):                  0.000
# Kurtosis:                 21.015           Condition No.:             1
# ===============================================================================
#
#                         Results: Ordinary least squares
# ===============================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.499
# Dependent Variable:     CAT              AIC:                         7668.7805
# Date:                   2021-11-17 15:51 BIC:                         7674.5410
# No. Observations:       2346             Log-Likelihood:              -3833.4
# Df Model:               1                F-statistic:                 190.6
# Df Residuals:           2345             Prob (F-statistic):          9.52e-42
# R-squared (uncentered): 0.499            Scale:                       1.5381
# -------------------------------------------------------------------------------------
#            Coef.        Std.Err.          z          P>|z|        [0.025       0.975]
# -------------------------------------------------------------------------------------
# DJIA       1.1613         0.0841       13.8068       0.0000       0.9965       1.3262
# -------------------------------------------------------------------------------
# Omnibus:                 332.430           Durbin-Watson:              1.965
# Prob(Omnibus):           0.000             Jarque-Bera (JB):           4543.882
# Skew:                    -0.056            Prob(JB):                   0.000
# Kurtosis:                9.817             Condition No.:              1
# ===============================================================================
#
#                         Results: Ordinary least squares
# ===============================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.288
# Dependent Variable:     CRM              AIC:                         9350.6142
# Date:                   2021-11-17 15:51 BIC:                         9356.3747
# No. Observations:       2346             Log-Likelihood:              -4674.3
# Df Model:               1                F-statistic:                 516.3
# Df Residuals:           2345             Prob (F-statistic):          1.79e-103
# R-squared (uncentered): 0.288            Scale:                       3.1502
# -------------------------------------------------------------------------------------
#            Coef.        Std.Err.          z          P>|z|        [0.025       0.975]
# -------------------------------------------------------------------------------------
# DJIA       1.0602         0.0467       22.7230       0.0000       0.9688       1.1517
# -------------------------------------------------------------------------------
# Omnibus:                  844.562          Durbin-Watson:             1.963
# Prob(Omnibus):            0.000            Jarque-Bera (JB):          29097.595
# Skew:                     1.035            Prob(JB):                  0.000
# Kurtosis:                 20.128           Condition No.:             1
# ===============================================================================
#
#                         Results: Ordinary least squares
# ===============================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.444
# Dependent Variable:     CSCO             AIC:                         7461.2316
# Date:                   2021-11-17 15:51 BIC:                         7466.9921
# No. Observations:       2346             Log-Likelihood:              -3729.6
# Df Model:               1                F-statistic:                 727.8
# Df Residuals:           2345             Prob (F-statistic):          7.64e-140
# R-squared (uncentered): 0.444            Scale:                       1.4079
# -------------------------------------------------------------------------------------
#            Coef.        Std.Err.          z          P>|z|        [0.025       0.975]
# -------------------------------------------------------------------------------------
# DJIA       0.9951         0.0369       26.9783       0.0000       0.9228       1.0674
# -------------------------------------------------------------------------------
# Omnibus:                  679.500          Durbin-Watson:             2.051
# Prob(Omnibus):            0.000            Jarque-Bera (JB):          81349.970
# Skew:                     -0.109           Prob(JB):                  0.000
# Kurtosis:                 31.847           Condition No.:             1
# ===============================================================================
#
#                         Results: Ordinary least squares
# ===============================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.532
# Dependent Variable:     CVX              AIC:                         7550.6935
# Date:                   2021-11-17 15:51 BIC:                         7556.4540
# No. Observations:       2346             Log-Likelihood:              -3774.3
# Df Model:               1                F-statistic:                 397.9
# Df Residuals:           2345             Prob (F-statistic):          6.78e-82
# R-squared (uncentered): 0.532            Scale:                       1.4626
# -------------------------------------------------------------------------------------
#            Coef.        Std.Err.          z          P>|z|        [0.025       0.975]
# -------------------------------------------------------------------------------------
# DJIA       1.2094         0.0606       19.9467       0.0000       1.0905       1.3282
# -------------------------------------------------------------------------------
# Omnibus:                  765.617          Durbin-Watson:             2.022
# Prob(Omnibus):            0.000            Jarque-Bera (JB):          47886.658
# Skew:                     -0.689           Prob(JB):                  0.000
# Kurtosis:                 25.091           Condition No.:             1
# ===============================================================================
#
#                         Results: Ordinary least squares
# ===============================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.470
# Dependent Variable:     DIS              AIC:                         7181.0767
# Date:                   2021-11-17 15:51 BIC:                         7186.8371
# No. Observations:       2346             Log-Likelihood:              -3589.5
# Df Model:               1                F-statistic:                 567.4
# Df Residuals:           2345             Prob (F-statistic):          1.71e-112
# R-squared (uncentered): 0.471            Scale:                       1.2494
# -------------------------------------------------------------------------------------
#            Coef.        Std.Err.          z          P>|z|        [0.025       0.975]
# -------------------------------------------------------------------------------------
# DJIA       0.9885         0.0415       23.8198       0.0000       0.9072       1.0699
# -------------------------------------------------------------------------------
# Omnibus:                  835.500          Durbin-Watson:             2.123
# Prob(Omnibus):            0.000            Jarque-Bera (JB):          29552.871
# Skew:                     1.009            Prob(JB):                  0.000
# Kurtosis:                 20.270           Condition No.:             1
# ===============================================================================
#
#                         Results: Ordinary least squares
# ===============================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.458
# Dependent Variable:     DD               AIC:                         8137.5744
# Date:                   2021-11-17 15:51 BIC:                         8143.3348
# No. Observations:       2346             Log-Likelihood:              -4067.8
# Df Model:               1                F-statistic:                 486.3
# Df Residuals:           2345             Prob (F-statistic):          4.28e-98
# R-squared (uncentered): 0.458            Scale:                       1.8784
# -------------------------------------------------------------------------------------
#            Coef.        Std.Err.          z          P>|z|        [0.025       0.975]
# -------------------------------------------------------------------------------------
# DJIA       1.1823         0.0536       22.0530       0.0000       1.0773       1.2874
# -------------------------------------------------------------------------------
# Omnibus:                  677.988          Durbin-Watson:             2.007
# Prob(Omnibus):            0.000            Jarque-Bera (JB):          25932.244
# Skew:                     0.654            Prob(JB):                  0.000
# Kurtosis:                 19.235           Condition No.:             1
# ===============================================================================
#
#                         Results: Ordinary least squares
# ===============================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.622
# Dependent Variable:     GS               AIC:                         6996.0201
# Date:                   2021-11-17 15:51 BIC:                         7001.7806
# No. Observations:       2346             Log-Likelihood:              -3497.0
# Df Model:               1                F-statistic:                 1979.
# Df Residuals:           2345             Prob (F-statistic):          6.62e-314
# R-squared (uncentered): 0.622            Scale:                       1.1547
# -------------------------------------------------------------------------------------
#            Coef.        Std.Err.          z          P>|z|        [0.025       0.975]
# -------------------------------------------------------------------------------------
# DJIA       1.2943         0.0291       44.4842       0.0000       1.2372       1.3513
# -------------------------------------------------------------------------------
# Omnibus:                 289.023           Durbin-Watson:              2.102
# Prob(Omnibus):           0.000             Jarque-Bera (JB):           1677.517
# Skew:                    0.425             Prob(JB):                   0.000
# Kurtosis:                7.054             Condition No.:              1
# ===============================================================================
#
#                         Results: Ordinary least squares
# ===============================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.543
# Dependent Variable:     HD               AIC:                         6513.0059
# Date:                   2021-11-17 15:51 BIC:                         6518.7664
# No. Observations:       2346             Log-Likelihood:              -3255.5
# Df Model:               1                F-statistic:                 353.4
# Df Residuals:           2345             Prob (F-statistic):          1.50e-73
# R-squared (uncentered): 0.543            Scale:                       0.93980
# -------------------------------------------------------------------------------------
#            Coef.        Std.Err.          z          P>|z|        [0.025       0.975]
# -------------------------------------------------------------------------------------
# DJIA       0.9924         0.0528       18.7991       0.0000       0.8889       1.0958
# -------------------------------------------------------------------------------
# Omnibus:                  437.076          Durbin-Watson:             2.014
# Prob(Omnibus):            0.000            Jarque-Bera (JB):          10741.298
# Skew:                     -0.126           Prob(JB):                  0.000
# Kurtosis:                 13.480           Condition No.:             1
# ===============================================================================
#
#                         Results: Ordinary least squares
# ===============================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.663
# Dependent Variable:     HON              AIC:                         5686.9486
# Date:                   2021-11-17 15:51 BIC:                         5692.7091
# No. Observations:       2346             Log-Likelihood:              -2842.5
# Df Model:               1                F-statistic:                 663.1
# Df Residuals:           2345             Prob (F-statistic):          5.58e-129
# R-squared (uncentered): 0.663            Scale:                       0.66087
# -------------------------------------------------------------------------------------
#            Coef.        Std.Err.          z          P>|z|        [0.025       0.975]
# -------------------------------------------------------------------------------------
# DJIA       1.0697         0.0415       25.7499       0.0000       0.9883       1.1511
# -------------------------------------------------------------------------------
# Omnibus:                  488.958          Durbin-Watson:             2.129
# Prob(Omnibus):            0.000            Jarque-Bera (JB):          15610.760
# Skew:                     -0.185           Prob(JB):                  0.000
# Kurtosis:                 15.632           Condition No.:             1
# ===============================================================================
#
#                         Results: Ordinary least squares
# ===============================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.502
# Dependent Variable:     IBM              AIC:                         6789.9457
# Date:                   2021-11-17 15:51 BIC:                         6795.7062
# No. Observations:       2346             Log-Likelihood:              -3394.0
# Df Model:               1                F-statistic:                 738.6
# Df Residuals:           2345             Prob (F-statistic):          1.27e-141
# R-squared (uncentered): 0.502            Scale:                       1.0576
# -------------------------------------------------------------------------------------
#            Coef.        Std.Err.          z          P>|z|        [0.025       0.975]
# -------------------------------------------------------------------------------------
# DJIA       0.9687         0.0356       27.1767       0.0000       0.8988       1.0386
# -------------------------------------------------------------------------------
# Omnibus:                  952.540          Durbin-Watson:             1.963
# Prob(Omnibus):            0.000            Jarque-Bera (JB):          33486.462
# Skew:                     -1.250           Prob(JB):                  0.000
# Kurtosis:                 21.339           Condition No.:             1
# ===============================================================================
#
#                         Results: Ordinary least squares
# ===============================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.408
# Dependent Variable:     INTC             AIC:                         8324.7903
# Date:                   2021-11-17 15:51 BIC:                         8330.5508
# No. Observations:       2346             Log-Likelihood:              -4161.4
# Df Model:               1                F-statistic:                 240.3
# Df Residuals:           2345             Prob (F-statistic):          1.14e-51
# R-squared (uncentered): 0.408            Scale:                       2.0344
# -------------------------------------------------------------------------------------
#            Coef.        Std.Err.          z          P>|z|        [0.025       0.975]
# -------------------------------------------------------------------------------------
# DJIA       1.1110         0.0717       15.5015       0.0000       0.9705       1.2514
# -------------------------------------------------------------------------------
# Omnibus:                  773.194          Durbin-Watson:             2.120
# Prob(Omnibus):            0.000            Jarque-Bera (JB):          32739.609
# Skew:                     -0.827           Prob(JB):                  0.000
# Kurtosis:                 21.226           Condition No.:             1
# ===============================================================================
#
#                         Results: Ordinary least squares
# ===============================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.427
# Dependent Variable:     JNJ              AIC:                         5747.0590
# Date:                   2021-11-17 15:51 BIC:                         5752.8195
# No. Observations:       2346             Log-Likelihood:              -2872.5
# Df Model:               1                F-statistic:                 544.5
# Df Residuals:           2345             Prob (F-statistic):          1.77e-108
# R-squared (uncentered): 0.427            Scale:                       0.67802
# -------------------------------------------------------------------------------------
#            Coef.        Std.Err.          z          P>|z|        [0.025       0.975]
# -------------------------------------------------------------------------------------
# DJIA       0.6667         0.0286       23.3355       0.0000       0.6107       0.7227
# -------------------------------------------------------------------------------
# Omnibus:                  770.440          Durbin-Watson:             1.937
# Prob(Omnibus):            0.000            Jarque-Bera (JB):          17832.606
# Skew:                     -1.003           Prob(JB):                  0.000
# Kurtosis:                 16.357           Condition No.:             1
# ===============================================================================
#
#                         Results: Ordinary least squares
# ===============================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.621
# Dependent Variable:     JPM              AIC:                         6843.4316
# Date:                   2021-11-17 15:51 BIC:                         6849.1921
# No. Observations:       2346             Log-Likelihood:              -3420.7
# Df Model:               1                F-statistic:                 1990.
# Df Residuals:           2345             Prob (F-statistic):          3.46e-315
# R-squared (uncentered): 0.622            Scale:                       1.0819
# -------------------------------------------------------------------------------------
#            Coef.        Std.Err.          z          P>|z|        [0.025       0.975]
# -------------------------------------------------------------------------------------
# DJIA       1.2507         0.0280       44.6065       0.0000       1.1958       1.3057
# -------------------------------------------------------------------------------
# Omnibus:                 419.035           Durbin-Watson:              2.012
# Prob(Omnibus):           0.000             Jarque-Bera (JB):           7278.148
# Skew:                    0.303             Prob(JB):                   0.000
# Kurtosis:                11.608            Condition No.:              1
# ===============================================================================
#
#                         Results: Ordinary least squares
# ===============================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.420
# Dependent Variable:     KO               AIC:                         5868.4778
# Date:                   2021-11-17 15:51 BIC:                         5874.2383
# No. Observations:       2346             Log-Likelihood:              -2933.2
# Df Model:               1                F-statistic:                 719.6
# Df Residuals:           2345             Prob (F-statistic):          1.77e-138
# R-squared (uncentered): 0.420            Scale:                       0.71404
# -------------------------------------------------------------------------------------
#            Coef.        Std.Err.          z          P>|z|        [0.025       0.975]
# -------------------------------------------------------------------------------------
# DJIA       0.6753         0.0252       26.8256       0.0000       0.6259       0.7246
# -------------------------------------------------------------------------------
# Omnibus:                  747.702          Durbin-Watson:             1.969
# Prob(Omnibus):            0.000            Jarque-Bera (JB):          16081.786
# Skew:                     -0.979           Prob(JB):                  0.000
# Kurtosis:                 15.676           Condition No.:             1
# ===============================================================================
#
#                         Results: Ordinary least squares
# ===============================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.450
# Dependent Variable:     MCD              AIC:                         6269.8770
# Date:                   2021-11-17 15:51 BIC:                         6275.6374
# No. Observations:       2346             Log-Likelihood:              -3133.9
# Df Model:               1                F-statistic:                 241.9
# Df Residuals:           2345             Prob (F-statistic):          5.49e-52
# R-squared (uncentered): 0.450            Scale:                       0.84728
# -------------------------------------------------------------------------------------
#            Coef.        Std.Err.          z          P>|z|        [0.025       0.975]
# -------------------------------------------------------------------------------------
# DJIA       0.7807         0.0502       15.5528       0.0000       0.6823       0.8791
# -------------------------------------------------------------------------------
# Omnibus:                  562.012          Durbin-Watson:             2.028
# Prob(Omnibus):            0.000            Jarque-Bera (JB):          13447.044
# Skew:                     0.552            Prob(JB):                  0.000
# Kurtosis:                 14.677           Condition No.:             1
# ===============================================================================
#
#                         Results: Ordinary least squares
# ===============================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.538
# Dependent Variable:     MMM              AIC:                         6148.5381
# Date:                   2021-11-17 15:51 BIC:                         6154.2986
# No. Observations:       2346             Log-Likelihood:              -3073.3
# Df Model:               1                F-statistic:                 334.4
# Df Residuals:           2345             Prob (F-statistic):          6.24e-70
# R-squared (uncentered): 0.538            Scale:                       0.80457
# -------------------------------------------------------------------------------------
#            Coef.        Std.Err.          z          P>|z|        [0.025       0.975]
# -------------------------------------------------------------------------------------
# DJIA       0.9081         0.0497       18.2852       0.0000       0.8108       1.0054
# -------------------------------------------------------------------------------
# Omnibus:                1210.557          Durbin-Watson:             1.948
# Prob(Omnibus):          0.000             Jarque-Bera (JB):          105826.457
# Skew:                   -1.531            Prob(JB):                  0.000
# Kurtosis:               35.760            Condition No.:             1
# ===============================================================================
#
#                         Results: Ordinary least squares
# ===============================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.326
# Dependent Variable:     MRK              AIC:                         6884.4198
# Date:                   2021-11-17 15:51 BIC:                         6890.1803
# No. Observations:       2346             Log-Likelihood:              -3441.2
# Df Model:               1                F-statistic:                 576.4
# Df Residuals:           2345             Prob (F-statistic):          4.61e-114
# R-squared (uncentered): 0.326            Scale:                       1.1010
# -------------------------------------------------------------------------------------
#            Coef.        Std.Err.          z          P>|z|        [0.025       0.975]
# -------------------------------------------------------------------------------------
# DJIA       0.6850         0.0285       24.0074       0.0000       0.6291       0.7409
# -------------------------------------------------------------------------------
# Omnibus:                 340.308           Durbin-Watson:              1.974
# Prob(Omnibus):           0.000             Jarque-Bera (JB):           4620.226
# Skew:                    0.138             Prob(JB):                   0.000
# Kurtosis:                9.869             Condition No.:              1
# ===============================================================================
#
#                         Results: Ordinary least squares
# ===============================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.488
# Dependent Variable:     MSFT             AIC:                         7340.5164
# Date:                   2021-11-17 15:51 BIC:                         7346.2769
# No. Observations:       2346             Log-Likelihood:              -3669.3
# Df Model:               1                F-statistic:                 962.8
# Df Residuals:           2345             Prob (F-statistic):          2.07e-177
# R-squared (uncentered): 0.488            Scale:                       1.3373
# -------------------------------------------------------------------------------------
#            Coef.        Std.Err.          z          P>|z|        [0.025       0.975]
# -------------------------------------------------------------------------------------
# DJIA       1.0601         0.0342       31.0292       0.0000       0.9931       1.1270
# -------------------------------------------------------------------------------
# Omnibus:                  470.191          Durbin-Watson:             2.013
# Prob(Omnibus):            0.000            Jarque-Bera (JB):          14586.441
# Skew:                     -0.081           Prob(JB):                  0.000
# Kurtosis:                 15.215           Condition No.:             1
# ===============================================================================
#
#                         Results: Ordinary least squares
# ===============================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.371
# Dependent Variable:     NKE              AIC:                         7863.1428
# Date:                   2021-11-17 15:51 BIC:                         7868.9032
# No. Observations:       2346             Log-Likelihood:              -3930.6
# Df Model:               1                F-statistic:                 507.3
# Df Residuals:           2345             Prob (F-statistic):          7.22e-102
# R-squared (uncentered): 0.371            Scale:                       1.6710
# -------------------------------------------------------------------------------------
#            Coef.        Std.Err.          z          P>|z|        [0.025       0.975]
# -------------------------------------------------------------------------------------
# DJIA       0.9322         0.0414       22.5244       0.0000       0.8511       1.0133
# -------------------------------------------------------------------------------
# Omnibus:                  954.013          Durbin-Watson:             2.050
# Prob(Omnibus):            0.000            Jarque-Bera (JB):          38182.579
# Skew:                     1.215            Prob(JB):                  0.000
# Kurtosis:                 22.614           Condition No.:             1
# ===============================================================================
#
#                         Results: Ordinary least squares
# ===============================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.343
# Dependent Variable:     PG               AIC:                         6164.2462
# Date:                   2021-11-17 15:51 BIC:                         6170.0067
# No. Observations:       2346             Log-Likelihood:              -3081.1
# Df Model:               1                F-statistic:                 289.5
# Df Residuals:           2345             Prob (F-statistic):          2.62e-61
# R-squared (uncentered): 0.343            Scale:                       0.80998
# -------------------------------------------------------------------------------------
#            Coef.        Std.Err.          z          P>|z|        [0.025       0.975]
# -------------------------------------------------------------------------------------
# DJIA       0.6104         0.0359       17.0149       0.0000       0.5401       0.6808
# -------------------------------------------------------------------------------
# Omnibus:                 423.699           Durbin-Watson:              1.913
# Prob(Omnibus):           0.000             Jarque-Bera (JB):           9787.179
# Skew:                    0.100             Prob(JB):                   0.000
# Kurtosis:                13.004            Condition No.:              1
# ===============================================================================
#
#                         Results: Ordinary least squares
# ===============================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.520
# Dependent Variable:     TRV              AIC:                         6590.7256
# Date:                   2021-11-17 15:51 BIC:                         6596.4860
# No. Observations:       2346             Log-Likelihood:              -3294.4
# Df Model:               1                F-statistic:                 161.6
# Df Residuals:           2345             Prob (F-statistic):          7.39e-36
# R-squared (uncentered): 0.520            Scale:                       0.97146
# -------------------------------------------------------------------------------------
#            Coef.        Std.Err.          z          P>|z|        [0.025       0.975]
# -------------------------------------------------------------------------------------
# DJIA       0.9621         0.0757       12.7133       0.0000       0.8138       1.1104
# -------------------------------------------------------------------------------
# Omnibus:                  778.874          Durbin-Watson:             2.130
# Prob(Omnibus):            0.000            Jarque-Bera (JB):          37478.680
# Skew:                     -0.800           Prob(JB):                  0.000
# Kurtosis:                 22.515           Condition No.:             1
# ===============================================================================
#
#                         Results: Ordinary least squares
# ===============================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.448
# Dependent Variable:     UNH              AIC:                         7477.4350
# Date:                   2021-11-17 15:51 BIC:                         7483.1955
# No. Observations:       2346             Log-Likelihood:              -3737.7
# Df Model:               1                F-statistic:                 356.3
# Df Residuals:           2345             Prob (F-statistic):          4.31e-74
# R-squared (uncentered): 0.448            Scale:                       1.4177
# -------------------------------------------------------------------------------------
#            Coef.        Std.Err.          z          P>|z|        [0.025       0.975]
# -------------------------------------------------------------------------------------
# DJIA       1.0058         0.0533       18.8751       0.0000       0.9014       1.1102
# -------------------------------------------------------------------------------
# Omnibus:                 283.980           Durbin-Watson:              1.993
# Prob(Omnibus):           0.000             Jarque-Bera (JB):           2816.506
# Skew:                    0.110             Prob(JB):                   0.000
# Kurtosis:                8.363             Condition No.:              1
# ===============================================================================
#
#                         Results: Ordinary least squares
# ===============================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.575
# Dependent Variable:     V                AIC:                         6618.1196
# Date:                   2021-11-17 15:51 BIC:                         6623.8800
# No. Observations:       2346             Log-Likelihood:              -3308.1
# Df Model:               1                F-statistic:                 1230.
# Df Residuals:           2345             Prob (F-statistic):          5.77e-217
# R-squared (uncentered): 0.575            Scale:                       0.98287
# -------------------------------------------------------------------------------------
#            Coef.        Std.Err.          z          P>|z|        [0.025       0.975]
# -------------------------------------------------------------------------------------
# DJIA       1.0818         0.0308       35.0677       0.0000       1.0214       1.1423
# -------------------------------------------------------------------------------
# Omnibus:                 339.033           Durbin-Watson:              2.093
# Prob(Omnibus):           0.000             Jarque-Bera (JB):           4839.564
# Skew:                    0.045             Prob(JB):                   0.000
# Kurtosis:                10.036            Condition No.:              1
# ===============================================================================
#
#                         Results: Ordinary least squares
# ===============================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.273
# Dependent Variable:     VZ               AIC:                         6333.6730
# Date:                   2021-11-17 15:51 BIC:                         6339.4335
# No. Observations:       2346             Log-Likelihood:              -3165.8
# Df Model:               1                F-statistic:                 304.3
# Df Residuals:           2345             Prob (F-statistic):          3.54e-64
# R-squared (uncentered): 0.273            Scale:                       0.87064
# -------------------------------------------------------------------------------------
#            Coef.        Std.Err.          z          P>|z|        [0.025       0.975]
# -------------------------------------------------------------------------------------
# DJIA       0.5367         0.0308       17.4453       0.0000       0.4764       0.5970
# -------------------------------------------------------------------------------
# Omnibus:                 255.422           Durbin-Watson:              1.934
# Prob(Omnibus):           0.000             Jarque-Bera (JB):           2177.814
# Skew:                    0.079             Prob(JB):                   0.000
# Kurtosis:                7.717             Condition No.:              1
# ===============================================================================
#
#                         Results: Ordinary least squares
# ===============================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.248
# Dependent Variable:     WBA              AIC:                         8738.8877
# Date:                   2021-11-17 15:51 BIC:                         8744.6482
# No. Observations:       2346             Log-Likelihood:              -4368.4
# Df Model:               1                F-statistic:                 177.8
# Df Residuals:           2345             Prob (F-statistic):          3.83e-39
# R-squared (uncentered): 0.248            Scale:                       2.4271
# -------------------------------------------------------------------------------------
#            Coef.        Std.Err.          z          P>|z|        [0.025       0.975]
# -------------------------------------------------------------------------------------
# DJIA       0.8404         0.0630       13.3327       0.0000       0.7169       0.9639
# -------------------------------------------------------------------------------
# Omnibus:                  770.007          Durbin-Watson:             1.911
# Prob(Omnibus):            0.000            Jarque-Bera (JB):          24425.344
# Skew:                     -0.908           Prob(JB):                  0.000
# Kurtosis:                 18.703           Condition No.:             1
# ===============================================================================
#
#                         Results: Ordinary least squares
# ===============================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.220
# Dependent Variable:     WMT              AIC:                         6931.1472
# Date:                   2021-11-17 15:51 BIC:                         6936.9077
# No. Observations:       2346             Log-Likelihood:              -3464.6
# Df Model:               1                F-statistic:                 110.2
# Df Residuals:           2345             Prob (F-statistic):          3.11e-25
# R-squared (uncentered): 0.221            Scale:                       1.1232
# -------------------------------------------------------------------------------------
#            Coef.        Std.Err.          z          P>|z|        [0.025       0.975]
# -------------------------------------------------------------------------------------
# DJIA       0.5292         0.0504       10.4999       0.0000       0.4304       0.6280
# -------------------------------------------------------------------------------
# Omnibus:                  706.819          Durbin-Watson:             2.006
# Prob(Omnibus):            0.000            Jarque-Bera (JB):          27783.044
# Skew:                     0.709            Prob(JB):                  0.000
# Kurtosis:                 19.799           Condition No.:             1
# ===============================================================================

# %% [markdown]
# **1.12** Make a scatter plot of $(\hat{\beta}_{i},\bar{r}_{i})$ and overlay it with a red regression line (the security market line). Add a title and legend, and label the axes:

# %%
linear_model = LinearRegression()
X, y   = beta, meanret 
linear_model.fit(X,y) # Fitting the linear model with data beta(X) and meanret(y)

# Plotting graphs
plt.figure(figsize=(10, 6))
matplotlib.pyplot.scatter(new_df['beta'], new_df['meanret'], alpha=1, label ='Individual stocks excess return')
plt.plot(X, linear_model.predict(X),color='r', label ='SML')

# Add a legend  
plt.legend()
plt.title('The SML and the 30 constituent stocks of the Dow ')
plt.xlabel("beta")
plt.ylabel("excess return")
plt.show()

# %% [markdown]
# ## Question 2: Value at Risk
# In this question we construct a VaR estimates for two stocks, one high risk and one low risk stock. Further, for the high risk stock, we split the sample into two periods to evaluate the VaR out-of-sample. You can re-use the data from the previous question.

# %% [markdown]
# **2.1** Use the above estimates to identify the most risky and the least risky stock in terms of their estimated betas. Create two `pandas` series `r_hirisk` and `r_lorisk` from the `df` DataFrame.

# %%
print('The highest risk stock :', new_df['beta'].idxmax()) # Check which stock has the highest beta
print('The lowest risk stock  :', new_df['beta'].idxmin()) # Check which stock has the lowest beta

r_hirisk = df[new_df['beta'].idxmax()]
r_lorisk = df[new_df['beta'].idxmin()]
# Out:
# The highest risk stock : BA
# The lowest risk stock  : WMT

# %% [markdown]
# **2.2** For both stocks, create a 1% VaR estimate, assuming a $t$ distribution. Comment on the difference between the estimates.

# %%
df, m, h = stats.t.fit(r_hirisk)  #fit a location-scale t distribution to r_hirisk
h_VaR_t = -stats.t.ppf(0.01, df, loc=m, scale=h) 
h_VaR_t, m, h, df
# Out:
# (6.021746594349676, 0.06691272736983948, 1.1245007600225838, 2.472251444766809)

# %%
df, m, h = stats.t.fit(r_lorisk)  #fit a location-scale t distribution to r_lorisk
l_VaR_t = -stats.t.ppf(0.01, df, loc=m, scale=h) 
l_VaR_t, m, h, df
# Out:
# (3.0781231140095766,
#  0.04819412908876472,
#  0.7296458256790824,
#  3.237626652530147)

# %% [markdown]
# **Answer the following questions for the *risky stock* only.**

# %% [markdown]
# **2.3** Test the fit of the Student's *t* distribution using a QQ plot, and give a conclusion in words.

# %%
sm.qqplot(r_hirisk , dist=stats.t, fit=True, line='45')
plt.title("QQ Plot vs. Student's $t$")
plt.show()

# %% [markdown]
# **2.4** Make a plot consisting of two subplots, the left of which shows $-R_t$ and $VaR^{0.01}$, and the right panel showing a histogram of $R_t$ overlaid with the fitted Student's *t* distribution. Make sure to add title, legend, and axis labels.
#
# *Hint*: The Value at Risk $VaR^{0.01}$ is constant over time, so the plot of the VaR will be a horizontal line.

# %%
plt.figure(figsize=(12, 4))
plt.subplot(121)
ax = sns.distplot(-r_hirisk, kde=False, fit=stats.t) 
ax.set_xticks([-h_VaR_t])
ax.set_xticklabels(['$-VaR_{t+1}^{0.01}$ = -%4.3f' %h_VaR_t])
plt.xlabel("$-R_t$")
plt.ylabel("Var")
plt.title('$-R_t$ and $VaR^{0.01}$')
plt.subplot(122)
plt.title(' $R_t$ overlaid with the fitted Students *t* distribution')
r_hirisk.plot()
plt.axhline(y=h_VaR_t, color='r', linestyle='-', label ='$VaR^{0.01}$')
plt.xlabel("$Year$")
plt.ylabel("$Var$")
plt.legend()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **2.5** Finally, split the sample of `r_hirisk` into two parts: one sample from 2012-2019, and one sample from 2020-2021. Use the first sample (2012-2019) to compute the 1% VaR assuming a Student's $t$ distribution as before. Then, use the second sample to evaluate the VaR by counting the number of exceedances in the period 2020-2021. Give a conclusion in words.
#
# *Bonus* Does your conclusion change if you evaluate the VaR based on returns in 2021 only?

# %%
before = r_hirisk[:'2019'] ; before
after  = r_hirisk['2020':] ; after
# Out:
# 2020-01-03   -0.172225
# 2020-01-06    0.289875
# 2020-01-07    1.050986
# 2020-01-08   -1.771929
# 2020-01-09    1.484563
#                 ...
# 2021-09-24    0.130991
# 2021-09-27    1.243315
# 2021-09-28   -2.598715
# 2021-09-29    3.132398
# 2021-09-30   -2.434543
# Name: BA, Length: 423, dtype: float64

# %%
df, m, h = stats.t.fit(before)  #fit a location-scale t distribution to r_hirisk
b_h_VaR_t = -stats.t.ppf(0.01, df, loc=m, scale=h) 
b_h_VaR_t, m, h, df
# Out:
# (3.8420451768997284,
#  0.10363356474126169,
#  1.0661126798390996,
#  4.091651330571398)

# %%
df, m, h = stats.t.fit(after)  #fit a location-scale t distribution to r_hirisk
a_h_VaR_t = -stats.t.ppf(0.01, df, loc=m, scale=h) 
a_h_VaR_t, m, h, df
# Out:
# (13.770377866253284,
#  -0.2480688504363512,
#  2.129134340838233,
#  2.1471164085420162)

# %%
# Evaluate the VaR based on returns in 2021 only
year_2021 = r_hirisk['2021']
df, m, h = stats.t.fit(year_2021)  #fit a location-scale t distribution to r_hirisk
h_VaR_t_2021 = -stats.t.ppf(0.01, df, loc=m, scale=h) 
h_VaR_t_2021, m, h, df
# Out:
# (5.612258277895633,
#  -0.10191429990982996,
#  1.8849798117699978,
#  7.702901821370139)
